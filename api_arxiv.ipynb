# %%
import os
import logging
import matplotlib.pyplot as plt
import pandas as pd
import json
from pandas import json_normalize
import pandas
import requests
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
url_sum= "https://api.rxivist.org/v1/authors"
#url_sum= "https://api.biorxiv.org/sum/m"
#url = "https://api.biorxiv.org/pub/2017-08-21/2021-05-20"
r = requests.get(url_sum)
x = r.json()
#df = pd.DataFrame(x['bioRxiv content statistics'])
df = pd.DataFrame(x['results'])
df.head()
display(df)
# Out:
#          id                  name  rank  downloads    tie
# 0    295517           James Gomes     1    1590267  False
# 1    580444           Parul Gupta     2    1590087  False
# 2    580447  Perumal Vivekanandan     3    1589903   True
# 3    580443       Akhilesh Mishra     3    1589903   True
# 4    580448       Bishwajit Kundu     3    1589903   True
# ..      ...                   ...   ...        ...    ...
# 195  755259         Vicki Herrera   196     232200  False
# 196  204724          Mark J. Daly   197     232027  False
# 197  363587           Saad B Omer   198     231851  False
# 198  755263         Kevin K Crown   199     231125  False
# 199  261163                Li Wei   200     231114  False
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         200 non-null    int64
#  1   name       200 non-null    object
#  2   rank       200 non-null    int64
#  3   downloads  200 non-null    int64
#  4   tie        200 non-null    bool
# dtypes: bool(1), int64(3), object(1)
# memory usage: 6.6+ KB

# %% [markdown]
# Crecimiento de bioRxive

# %% [markdown]
# NUEVOS PAPERS

# %%
var = 'new_papers'
data = pd.concat([df[var], df['month']], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
plt.xticks(rotation=90)
fig = sns.barplot(x='month', y=var, data=data)
fig.axis(ymin=0, ymax=8000);

# %%
var = 'new_papers_cumulative'
data = pd.concat([df[var], df['month']], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
plt.xticks(rotation=90)
fig = sns.barplot(x='month', y=var, data=data)
fig.axis(ymin=0, ymax=160000);

# %%
var = 'revised_papers'
data = pd.concat([df[var], df['month']], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
plt.xticks(rotation=90)
fig = sns.barplot(x='month', y=var, data=data)
fig.axis(ymin=0, ymax=4000);

# %%
var = 'revised_papers_cumulative'
data = pd.concat([df[var], df['month']], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
plt.xticks(rotation=90)
fig = sns.barplot(x='month', y=var, data=data)
fig.axis(ymin=0, ymax=100000);

# %% [markdown]
# Tiempo de publicación
